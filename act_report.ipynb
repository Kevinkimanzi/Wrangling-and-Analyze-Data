# %% [markdown]
# # WE RATEDOGS INSIGHTS

# %% [markdown]
# **INTRODUCTION**

# %% [markdown]
# We Rate Dogs is twitter account that does exactly what it says. It rate dogs. People submit photos of their dogs, and the owner of we WeRateDogs account posts them with funny comments and a “rating” on a scale from one to 10 — but he often awards ratings exceeding the maximum, like “13/10.”   Most  of  the  time,  ten  is  used  as  the  denominator  in  these ratings.On the other hand? Every time, the value is greater than ten, as shown by the  numbers  ten/10 and  eleven/10,  as  well  as twelve  ten,  thirteen ten, and so  on. WeRateDogs  has  gained  extensive international  media  coverage  as  a  result  of  its  more  than  9 million followers.This account has alot of data like those who have retweeted, rating, date of posting, text about the dogs and breed of the dog.This huge amount of data may be acquired, analyzed, cleansed, and integrated with other data using data wrangling techniques to provide insight into the data's relationship with other data.

# %% [markdown]
# #### Which breed is common in twitter archives

# %% [markdown]
# There are also predictions for the various dog breeds included in the data.Golden_Retriever is the most common breed in this twitter archiver with 150 tweets followed by Labrador_retriever and Pembroke. respectively. cocker_spaniel had the least tweets followed by Pomeranian respectively

# %% [markdown]
# ![download1.png](attachment:download1.png)

# %% [markdown]
# ### DOG'S STAGE'S RATIO

# %% [markdown]
# In  the  WeRateDogs  twitter  account,  Pupper is the most popular Dog stage followed by doggo,puppo, multiple and the least is floofer.

# %% [markdown]
# ![download2.png](attachment:download2.png)

# %% [markdown]
# ### Visualizing the total number of tweets over time

# %% [markdown]
# WeRateDogs account started in 2005,tweeted alot in its starting date. It posted alot around 320 tweets in the month of January 2006. However its tweeting activity reduced drastically in the subsequent year.

# %% [markdown]
# ![download3.png](attachment:download3.png)
